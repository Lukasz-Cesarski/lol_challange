# %%
# %load_ext autoreload
# %autoreload 2

# %%
from lolchal import read_image_path, plot_screen, IMAGE_PATHS, plot_health_bars

# %%
image, health_bars_save_path, df_health_bars = read_image_path(IMAGE_PATHS[0])
assert df_health_bars is not None

# %%
plot_screen(image, df_health_bars)

# %%
plot_health_bars(image, df_health_bars)

# %%
# img = cv2.imread('ultrasound.png')
# mask = cv2.threshold(img, 210, 255, cv2.THRESH_BINARY)[1][:,:,0]
# dst = cv2.inpaint(img, mask, 7, cv2.INPAINT_NS)
