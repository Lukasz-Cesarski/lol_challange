# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import pandas as pd

from lolchal import read_image_path, plot_screen, IMAGE_PATHS, plot_health_bars, HB_HEIGHT, HB_WIDTH

# %%
image_path = IMAGE_PATHS[3]
image_path
# Out:
# 'starter/task_examples/screen4.png'

# %%
image, health_bars_save_path, df_health_bars = read_image_path(image_path)

# %%
coords = [
(891,207,1,1,1,1),
(974,423,1,1,1,1),
(1076,405,1,1,1,1),
(1264,0,0,0,0,1),
]
df_healthbars_new = pd.DataFrame(
    coords,
    columns = ["x", "y", "left", "top", "right", "bot"]
)
plot_screen(image, df_healthbars_new)

# %%
os.makedirs(os.path.dirname(health_bars_save_path), exist_ok=True)
# df_healthbars_new.to_csv(health_bars_save_path, index=False)

# %%
pd.read_csv(health_bars_save_path)
# Out:
#       x    y  left  top  right  bot
# 0   891  207     1    1      1    1
# 1   974  423     1    1      1    1
# 2  1076  405     1    1      1    1
# 3  1264    0     0    0      0    1

# %%
plot_health_bars(image, df_healthbars_new)

# %%
# img = cv2.imread('ultrasound.png')
# mask = cv2.threshold(img, 210, 255, cv2.THRESH_BINARY)[1][:,:,0]
# dst = cv2.inpaint(img, mask, 7, cv2.INPAINT_NS)
